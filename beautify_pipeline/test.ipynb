# %%
import sys
sys.path.append('/app')
from beautify_pipeline.pipeline import pipeline
# Out:
# Using TensorFlow backend.

# %%
import base64

image_path = '/app/raw_images_old/test.jpg'

# image to base64
with open(image_path, 'rb') as image_file:
    encoded_string = base64.b64encode(image_file.read()).decode('utf-8')

# base64 to image
with open('/app/decoded_image.jpg', 'wb') as image_file:
    image_file.write(base64.b64decode(encoded_string))

# %%
pipeline(encoded_string)
# Out:
# 5b652996-ba12-4f9d-a238-2d7541e53bef
# saving image...
# aligning image...

# %%
import base64

image_path = '/app/raw_images_old/13.jpg'

# image to base64
with open(image_path, 'rb') as image_file:
    encoded_string = base64.b64encode(image_file.read()).decode('utf-8')

# base64 to image
with open('/app/decoded_image.jpg', 'wb') as image_file:
    image_file.write(base64.b64decode(encoded_string))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-bca9e1b504ff> in <module>
#       4
#       5 # image to base64
# ----> 6 with open(image_path, 'rb') as image_file:
#       7     encoded_string = base64.b64encode(image_file.read()).decode('utf-8')
#       8
#
# FileNotFoundError: [Errno 2] No such file or directory: '/app/generated_images/test2_01.png'

# %%
pipeline(encoded_string)
# Out:
# c399104d-e9d0-4e99-ba4a-8fd9231eb8dc
# saving image...
# aligning image...
# encoding image...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Rects:
# rectangles[[(46, 81) (201, 236)]]
# Saving mask assets/c399104d-e9d0-4e99-ba4a-8fd9231eb8dc/masks/beautified_image_01.png
# Loading mask assets/c399104d-e9d0-4e99-ba4a-8fd9231eb8dc/masks/beautified_image_01.png
# beautified_image_01  Loss 140.6898
# 100%|██████████| 1/1 [00:13<00:00, 13.28s/it]
# fitting face...
# Done!
# transforming image to base64...
# Done!
# '...'
